# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
from app.ingestion.pdf_loader import PDFLoader

# %%
from app.core.config import RAW_PDF_DIR

loader = PDFLoader(str(RAW_PDF_DIR))
# Out:
# 17:19:29 | INFO | PDF directory set to: /Users/apple/Desktop/Research_Agent/data/raw_pdfs
# 17:19:29 | INFO | Found 1 PDF file(s).
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 from app.core.config import RAW_PDF_DIR
#       2
# ----> 3 loader = PDFLoader(str(RAW_PDF_DIR))
#
# TypeError: __init__() should return None, not 'list'

# %%
documents = loader.process_directory()

document = documents[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 documents = loader.process_directory()
#       2
#       3 document = documents[0]
#
# NameError: name 'loader' is not defined

# %%
documents = loader.process_directory()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 documents = loader.process_directory()
#
# NameError: name 'loader' is not defined

# %%
document = documents[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 document = documents[0]
#
# NameError: name 'documents' is not defined

# %%
len(documents)
# Out:
# 1

# %%
documents[0].keys()
# Out:
# dict_keys(['filename', 'filepath', 'metadata', 'pages'])

# %%
documents[0]["metadata"]
# Out:
# {'title': '',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'creator': 'LaTeX with hyperref',
#  'producer': 'pdfTeX-1.40.25',
#  'creation_date': 'D:20240410211143Z',
#  'modification_date': 'D:20240410211143Z',
#  'pages': 15}

# %%
documents[0]["pages"][0]
# Out:
# {'page': 1,
# ...

# %%
documents[0]["pages"][0]["text"]
# Out:
# 'Provided proper attribution is provided, Google hereby grants permission to\nreproduce the tables and figures in this paper solely for use in journalistic or\nscholarly works.\nAttention Is All You Need\nAshish Vaswani∗\nGoogle Brain\navaswani@google.com\nNoam Shazeer∗\nGoogle Brain\nnoam@google.com\nNiki Parmar∗\nGoogle Research\nnikip@google.com\nJakob Uszkoreit∗\nGoogle Research\nusz@google.com\nLlion Jones∗\nGoogle Research\nllion@google.com\nAidan N. Gomez∗†\nUniversity of Toronto\naidan@cs.toronto.edu\nŁukasz Kaiser∗\nGoogle Brain\nlukaszkaiser@google.com\nIllia Polosukhin∗‡\nillia.polosukhin@gmail.com\nAbstract\nThe dominant sequence transduction models are based on complex recurrent or\nconvolutional neural networks that include an encoder and a decoder. The best\nperforming models also connect the encoder and decoder through an attention\nmechanism. We propose a new simple network architecture, the Transformer,\nbased solely on attention mechanisms, dispensing with recurren
# ...

# %%
type(documents)
# Out:
# list

# %%
type(documents[0])
# Out:
# dict

# %%
from app.core.logger import logger

logger.info("Logger is working!")
logger.warning("Warning message")
logger.error("Error message")
# Out:
# 02:41:04 | INFO | Logger is working!
# 02:41:04 | WARNING | Warning message
# 02:41:04 | ERROR | Error message

# %%
from app.ingestion.pdf_loader import PDFLoader
from app.core.config import RAW_PDF_DIR

loader = PDFLoader(RAW_PDF_DIR)
print(loader.load_directory())

# %%
import fitz

pdf = fitz.open(str(RAW_PDF_DIR / "Attention_Research_Paper.pdf"))

page = pdf.load_page(0)

print(type(page))

print(page.get_text("text")[:300]) # type: ignore

pdf.close()
# Out:
# <class 'pymupdf.Page'>
# Provided proper attribution is provided, Google hereby grants permission to
# reproduce the tables and figures in this paper solely for use in journalistic or
# scholarly works.
# Attention Is All You Need
# Ashish Vaswani∗
# Google Brain
# avaswani@google.com
# Noam Shazeer∗
# Google Brain
# noam@google.com
# Niki Par
